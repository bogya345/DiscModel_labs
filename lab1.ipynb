# %%
import pandas as pd

# %%
choosenCountryName = 'Kazakhstan'
choosenCountryCode = 398

# %% [markdown]
# # Determine the «survival» rates independently for men and women for all age groups (“0-4” -> “5-9” -> “10-14” ...) according to 2000-2005 years (data for Russia or any other country)

# %%
# data about 
# path2 = './storage/WPP2019_FERT_F01_BIRTHS_BOTH_SEXES.xlsx'
path_age_data = './storage/age_data_2005.xls'
# sheet2m = 'm; 1950-2005, estimates'
# sheet2f = 'f; 1950-2005, estimates'
sheet2m = 'm; 2010-50, medium-fertility'
sheet2f = 'f; 2010-50, medium-fertility'

# %%
cols = [
    'Index', 'Variant', 'Area', 'Notes',
    'Country_code', 'Reference_date',
    '0 - 4', '5 - 9', '10 - 14', '15 - 19',
    '20 - 24', '25 - 29', '30 - 34', '35 - 39',
    '40 - 44', '45 - 49', '50 - 54', '55 - 59', '60 - 64',
    '65 - 69', '70 - 74', '75 - 79', '80 - 84', '85 - 89', '90 - 94',
    '95 - 99', '100+'
]
cols_ext_period = [ 'Reference_date', 'Sex',
    '0 - 4', '5 - 9', '10 - 14', '15 - 19',
    '20 - 24', '25 - 29', '30 - 34', '35 - 39',
    '40 - 44', '45 - 49', '50 - 54', '55 - 59', '60 - 64',
    '65 - 69', '70 - 74', '75 - 79', '80 - 84'
    # ,'85 - 89', '90 - 94', '95 - 99', '100+'
]
cols_period = [
    '0 - 4', '5 - 9', '10 - 14', '15 - 19',
    '20 - 24', '25 - 29', '30 - 34', '35 - 39',
    '40 - 44', '45 - 49', '50 - 54', '55 - 59', '60 - 64',
    '65 - 69', '70 - 74', '75 - 79', '80 - 84'
    # ,'85 - 89', '90 - 94', '95 - 99', '100+'
]

# %%
dfm = pd.read_excel(path_age_data, sheet_name=sheet2m)
dfm.columns = cols
dfm.dropna(subset=['Index', 'Variant', 'Area'], inplace=True)
dfm = dfm.iloc[1: , :]
dfm['Sex'] = 'm'
dfm
# Out:
#      Index Variant   Area Notes Country_code Reference_date       0 - 4  \
# 6        0  Medium  WORLD   NaN          900           2010  324453.051
# 7        0  Medium  WORLD   NaN          900           2015  332039.152
# 8        0  Medium  WORLD   NaN          900           2020   331693.21
# 9        0  Medium  WORLD   NaN          900           2025  325721.711
# 10       0  Medium  WORLD   NaN          900           2030  319583.011
# ...    ...     ...    ...   ...          ...            ...         ...
# 2026   259  Medium  Tonga   NaN          776           2030       4.067
# 2027   259  Medium  Tonga   NaN          776           2035       3.567
# 2028   259  Medium  Tonga   NaN          776           2040       2.997
# 2029   259  Medium  Tonga   NaN          776           2045       2.467
# 2030   259  Medium  Tonga   NaN          776           2050       1.992
#
#            5 - 9     10 - 14     15 - 19  ...     60 - 64     65 - 69  \
# 6     310015.285  306138.861   308097.76  ...  115546.475   83920.135
# 7     318537.914  308006.748  304640.396  ...  140169.446  102584.743
# 8     326749.369  316675.114  306600.863  ...  154172.517  125079.555
# 9      327066.55   325143.53  315364.115  ...  175198.142  138300.977
# 10    321714.812  325704.853  323932.697  ...  194019.158   158169.25
# ...          ...         ...         ...  ...         ...         ...
# 2026       4.148       4.404       4.259  ...       2.627       1.814
# 2027       3.748       3.995       3.855  ...       2.204        2.38
# 2028       3.249       3.596       3.447  ...       2.524       2.015
# 2029        2.68       3.097       3.048  ...       3.182       2.316
# 2030       2.151       2.529        2.55  ...       2.853       2.928
#
#          70 - 74    75 - 79    80 - 84    85 - 89   90 - 94   95 - 99  \
# 6      64827.917  43392.716  24623.641  10130.297   2814.41   579.507
# 7      69794.857   48624.43  27908.199  12593.943  3801.933   710.932
# 8      86125.931  53234.511  31788.912  14568.028  4848.809   984.569
# 9     105630.162  66460.298  35498.631  16928.036    5737.2   1290.96
# 10    117664.376  82109.358  45013.187  19405.719  6846.228  1568.629
# ...          ...        ...        ...        ...       ...       ...
# 2026       1.265      0.955      0.504      0.245     0.086     0.016
# 2027        1.54      0.964       0.63      0.262     0.091      0.02
# 2028       2.032      1.188      0.645      0.335       0.1     0.022
# 2029       1.738      1.585      0.807       0.35     0.131     0.024
# 2030        2.01       1.37      1.091      0.447     0.141     0.033
#
#          100+ Sex
# 6      70.612   m
# 7      96.705   m
# 8     122.498   m
# 9     168.187   m
# 10    224.869   m
# ...       ...  ..
# 2026    0.002   m
# 2027    0.002   m
# 2028    0.002   m
# 2029    0.003   m
# 2030    0.003   m
#
# [2025 rows x 28 columns]

# %%
dff = pd.read_excel(path_age_data, sheet_name=sheet2f)
dff.columns = cols
dff.dropna(subset=['Index', 'Variant', 'Area'], inplace=True)
dff = dff.iloc[1: , :]
dff['Sex'] = 'f'
dff
# Out:
#      Index Variant   Area Notes Country_code Reference_date       0 - 4  \
# 6        0  Medium  WORLD   NaN          900           2010  308533.785
# 7        0  Medium  WORLD   NaN          900           2015  315805.329
# 8        0  Medium  WORLD   NaN          900           2020  315649.009
# 9        0  Medium  WORLD   NaN          900           2025  310182.964
# 10       0  Medium  WORLD   NaN          900           2030    304844.9
# ...    ...     ...    ...   ...          ...            ...         ...
# 2026   259  Medium  Tonga   NaN          776           2030       3.893
# 2027   259  Medium  Tonga   NaN          776           2035       3.419
# 2028   259  Medium  Tonga   NaN          776           2040        2.88
# 2029   259  Medium  Tonga   NaN          776           2045       2.379
# 2030   259  Medium  Tonga   NaN          776           2050        1.93
#
#            5 - 9     10 - 14     15 - 19  ...     60 - 64     65 - 69  \
# 6     294657.693  290611.684  292432.301  ...  122511.733   93635.052
# 7     303018.991  292885.218  289573.031  ...  148308.309  113789.754
# 8      310982.69  301400.962  291929.141  ...  162404.154  138320.502
# 9     311508.632  309625.656  300538.936  ...  185253.907  152021.971
# 10    306661.641  310398.204  308865.187  ...  204234.111  174135.457
# ...          ...         ...         ...  ...         ...         ...
# 2026        3.86       4.279        3.98  ...       2.447       1.328
# 2027       3.483       3.896         3.6  ...       2.103       1.881
# 2028       3.011       3.519       3.218  ...       2.352       1.567
# 6  698.542  501.647  484.327  292.428
# 7  751.438  590.390  391.894  333.865
# 8  816.533  639.791  465.271  272.602

# %%
def survavial_rate(
    start_previous, start_next): return start_next/start_previous

# %%
# тут надо со вдвигом по Reference_year (diagonal)

# %%
labels = [f"{cols_period[i-1]}/{cols_period[i]}" for i in range(1,len(cols_period)) ]
print(labels)
# Out:
# ['0 - 4/5 - 9', '5 - 9/10 - 14', '10 - 14/15 - 19', '15 - 19/20 - 24', '20 - 24/25 - 29', '25 - 29/30 - 34', '30 - 34/35 - 39', '35 - 39/40 - 44', '40 - 44/45 - 49', '45 - 49/50 - 54', '50 - 54/55 - 59', '55 - 59/60 - 64', '60 - 64/65 - 69', '65 - 69/70 - 74', '70 - 74/75 - 79', '75 - 79/80 - 84']

# %%
# surv_rates_both = pd.DataFrame([], columns=['Referenced_date',*labels])
# # surv_rates

# tmp_survs = []
# for row_ind in range(1, d2.shape[0]):

#     year_cur_data = d2.iloc[row_ind-1]
#     year_next_data = d2.iloc[row_ind]
#     coefs = []
#     for col_ind in range(1, len(cols2_period)):
#         cur_alive = year_cur_data[cols2_period[col_ind-1]]
#         next_alive = year_next_data[cols2_period[col_ind]]
#         # print(cur_alive, next_alive)

#         coefs.append(cur_alive/next_alive)

#         continue
#     # print('===============', coefs)

#     tmp_rec = pd.DataFrame([[int(d2.iloc[row_ind].Reference_date),
#                             # 0,
#                             *coefs]], columns=['Referenced_date',*labels])
#     # print(tmp_rec)
    
#     surv_rates_both = surv_rates_both.append(tmp_rec)

#     continue

# surv_rates_both

# %%
dmal = d[ d.Sex=='m' ]
dmal
# Out:
#     Reference_date Sex    0 - 4    5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  \
# 744           2010   m   551.44  527.118  532.465   620.22   778.31  637.738
# 745           2015   m  560.964  535.575   510.62  513.625  598.343  753.341
# 746           2020   m  529.328  545.992  519.458  492.345  493.513  577.038
# 747           2025   m   477.05  515.627   530.16  501.498  473.038  474.543
# 748           2030   m  432.262  464.478  500.129  512.439  482.632   455.06
# 749           2035   m  412.229  420.541  449.313  482.758  493.958   465.22
# 750           2040   m  407.092  401.026  405.625  432.285  464.814   477.01
# 751           2045   m  396.271  396.252  386.269  388.865  414.888  448.552
# 752           2050   m  370.329  385.729  381.596  369.668  371.874  399.296
#
#      30 - 34  35 - 39  40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  \
# 744   567.77  523.364  432.198  503.798  425.954  351.155  184.392  131.194
# 745  612.803  539.539  493.586  402.865  462.056  379.858  297.755  146.689
# 746   727.52  584.873  510.888  463.401  370.099  415.447  325.547  241.842
# 747  555.616  699.145  556.856  482.175  429.368  334.252  359.579  267.264
# 748  455.637  531.765  670.298  528.565  449.493  391.097  290.714  298.047
# 749  437.215  434.351  507.883  640.501  495.845  412.113  343.448  242.355
# 750  447.946  416.953  413.271  484.482  605.008  457.594  364.654  289.113
# 751  460.229  428.237  396.955  393.521  457.616  562.101  407.925  309.355
# 752  432.476  440.966   408.75  378.515  371.615  425.973  505.132  348.904
#
#      70 - 74  75 - 79 80 - 84
# 744  168.297   64.555   48.55
# 745   96.529  110.456  35.265
# 746  110.007   64.368  62.016
# 747  184.495   74.449  36.549
# 748  206.016  126.831  42.949
# 749  232.052  143.335  74.471
# 750  190.109  163.421  85.416
# 751   229.04  135.191  98.719
# 752  247.346  164.874  82.751

# %%
dfem = d[ d.Sex=='f' ]
dfem
# Out:
#     Reference_date Sex    0 - 4    5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  \
# 744           2010   f   531.77  511.709  514.952  599.523  765.301  635.753
# 745           2015   f  539.964  518.813  496.341  497.993  583.288  751.329
# 746           2020   f  508.932  527.435  503.575  479.603  482.544  570.742
# 747           2025   f  457.419  497.143  512.333  487.001  464.555  470.824
# 748           2030   f  413.186  446.279  482.198  495.883   472.18  453.168
# 749           2035   f  392.968  402.536  431.486  465.912  481.258      461
# 750           2040   f  387.226  382.596  387.845  415.334  451.482  470.186
# 751           2045   f  376.189  377.026  367.962  371.788  401.086  440.572
# 752           2050   f  350.997  366.153  362.429  351.962  357.684  390.365
#
#      30 - 34  35 - 39  40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  \
# 744  597.109   546.17  468.756  571.169  504.985  453.326  251.553  210.912
# 745  621.074  579.138  528.359   452.63  549.254  480.626  420.559  223.923
# 746  736.581  603.524  561.675  512.069   434.79  524.758  448.107  379.611
# 747  557.292  718.853   586.43  545.648  493.756   415.44  491.486  406.691
# 748  458.066  540.962  701.366  570.758  527.492  473.495  389.159   448.49
# 749  440.696  442.512   525.28  684.969  552.927  507.192  445.614  355.557
# 750  448.632  425.383  427.765  511.397  665.832  532.845  479.023  409.429
# 751  457.879  433.402  410.924  415.244  495.893   643.65  504.757  442.083
# 752  428.427  442.722  419.058  398.835  401.751  478.858  612.251  467.629
#
#      70 - 74  75 - 79  80 - 84
# 744  279.557  117.081  122.937
# 745  177.331  217.305   78.018
# 746  190.002  138.366  148.452
# 747  327.128  149.999   95.317
# 748  352.934  262.856  104.953
# 749  391.772  286.264  187.451
# 750  311.538  320.906  207.012
# 751   361.35  256.703  235.146
# 752  392.445  300.397  189.851

# %%
def calc_surv_rates(data, labels):
    surv_rates = pd.DataFrame([], columns=['Referenced_date', *labels])
    # surv_rates_m = pd.DataFrame([], columns=col2)
    # surv_rates

    tmp_survs = []
    for row_ind in range(1, data.shape[0]):

        year_cur_data = data.iloc[row_ind-1]
        year_next_data = data.iloc[row_ind]
        coefs = []
        for col_ind in range(1, len(cols_period)):
            cur_alive = year_cur_data[cols_period[col_ind-1]]
            next_alive = year_next_data[cols_period[col_ind]]
            # print(cur_alive, next_alive)

            coefs.append(cur_alive/next_alive)

            continue
        # print('===============', coefs)

        tmp_rec = pd.DataFrame([[int(data.iloc[row_ind].Reference_date),
                                # 0,
                                *coefs]], columns=['Referenced_date', *labels])
        # print(tmp_rec)
        
        surv_rates = surv_rates.append(tmp_rec)

        continue

    return surv_rates

# %%
surv_rate_m = pd.DataFrame([calc_surv_rates(dmal, labels).mean()], columns=labels)
surv_rate_m
# Out:
#    0 - 4/5 - 9  5 - 9/10 - 14  10 - 14/15 - 19  15 - 19/20 - 24  \
# 0     1.027647       1.033915         1.038447         1.040108
#
#    20 - 24/25 - 29  25 - 29/30 - 34  30 - 34/35 - 39  35 - 39/40 - 44  \
# 0         1.037226         1.038655         1.046603          1.05073
#
#    40 - 44/45 - 49  45 - 49/50 - 54  50 - 54/55 - 59  55 - 59/60 - 64  \
# 0         1.055594         1.071644         1.095444         1.144341
#
#    60 - 64/65 - 69  65 - 69/70 - 74  70 - 74/75 - 79  75 - 79/80 - 84
# 0         1.206017         1.296612          1.45103         1.722066

# %%
surv_rate_f = pd.DataFrame([calc_surv_rates(dfem, labels).mean()], columns=labels)
surv_rate_f
# Out:
#    0 - 4/5 - 9  5 - 9/10 - 14  10 - 14/15 - 19  15 - 19/20 - 24  \
# 0     1.025679       1.034238         1.037332         1.032617
#
#    20 - 24/25 - 29  25 - 29/30 - 34  30 - 34/35 - 39  35 - 39/40 - 44  \
# 0         1.023828         1.025842         1.031935         1.031578
#
#    40 - 44/45 - 49  45 - 49/50 - 54  50 - 54/55 - 59  55 - 59/60 - 64  \
# 0         1.029477         1.034785          1.04181         1.064252
#
#    60 - 64/65 - 69  65 - 69/70 - 74  70 - 74/75 - 79  75 - 79/80 - 84
# 0          1.09685         1.153282         1.243692          1.41841

# %% [markdown]
# # Determine the fertility rate for women in the age category “20- ... -39”

# %%
def fertility(amount_births, amount_women):
    return ( amount_births / amount_women ) #* 1e3

# %%
# amount_births = d2[ (d2['Reference_date']==2010) ]['0 - 4'].sum()
# amount_women = ( d2[ (d2['Reference_date']==2010) & (d2['Sex']=='f') ][['20 - 24','25 - 29','30 - 34','35 - 39']].sum() ).sum()

amount_births = d['0 - 4'].sum()
# amount_women = ( d[ (d['Sex']=='f') ][['20 - 24','25 - 29','30 - 34','35 - 39']].sum() ).sum()
amount_women = ( dfem[['20 - 24','25 - 29','30 - 34','35 - 39']].sum() ).sum()

amount_births, amount_women
# Out:
# (8095.616, 18581.738999999998)

# %%
coef_fertility = fertility(amount_births, amount_women)
coef_fertility
# Out:
# 0.43567590740565243

# %%
popularities = pd.DataFrame([d[cols_period].sum()], columns=cols_period)
popularities
# Out:
#       0 - 4     5 - 9   10 - 14   15 - 19   20 - 24   25 - 29   30 - 34  \
# 0  8095.616  8222.028  8274.756  8478.702  9030.748  9331.737  9442.968
#
#     35 - 39   40 - 44   45 - 49   50 - 54  55 - 59   60 - 64   65 - 69  \
# 0  9331.859  9020.298  8940.542  8693.734  8239.78  7121.655  5619.088
#
#     70 - 74   75 - 79   80 - 84
# 0  4447.948  3097.357  1935.823

# %%
vals = popularities.values[0]

tmp = []

for i in range(1, len(vals)):
    prev_births = vals[i-1] #* 1e3
    amount_women = d[ d['Sex']=='m' ][popularities.columns[i-1]].sum()
    # print(amount_women, popularities.columns[i])

    births = vals[i]
    
    x = fertility(births, amount_women)
    tmp.append(x)
    continue

print(tmp)
# Out:
# [1.9874540877188953, 1.9737807400071277, 2.0112514484769197, 2.0935024965789255, 2.0413436234651754, 2.0143717796713934, 1.986680396797079, 1.961278424280086, 2.0362522021051386, 2.0322799704429095, 2.025982443311547, 1.9095007762247322, 1.8248852116788221, 1.9553456777695084, 1.8615143660251785, 1.8480763355863594]

# %%
r2 = pd.DataFrame([tmp], columns=cols_period[1:])
r2
# Out:
#       5 - 9   10 - 14   15 - 19   20 - 24   25 - 29   30 - 34  35 - 39  \
# 0  1.987454  1.973781  2.011251  2.093502  2.041344  2.014372  1.98668
#
#     40 - 44   45 - 49  50 - 54   55 - 59   60 - 64   65 - 69   70 - 74  \
# 0  1.961278  2.036252  2.03228  2.025982  1.909501  1.824885  1.955346
#
#     75 - 79   80 - 84
# 0  1.861514  1.848076

# %% [markdown]
# # Calculate boys/girls ratio for newborn children

# %%
dsum = pd.DataFrame([d[cols_period].sum()], columns=cols_period)
dsum
# Out:
#       0 - 4     5 - 9   10 - 14   15 - 19   20 - 24   25 - 29   30 - 34  \
# 0  8095.616  8222.028  8274.756  8478.702  9030.748  9331.737  9442.968
#
#     35 - 39   40 - 44   45 - 49   50 - 54  55 - 59   60 - 64   65 - 69  \
# 0  9331.859  9020.298  8940.542  8693.734  8239.78  7121.655  5619.088
#
#     70 - 74   75 - 79   80 - 84
# 0  4447.948  3097.357  1935.823

# %%
tmpm = d[ d['Sex'] == 'm' ][cols_period].sum() / dsum[cols_period].sum()
tmpf = d[ d['Sex'] == 'f' ][cols_period].sum() / dsum[cols_period].sum()

r3 = pd.DataFrame([], columns=cols_period)
r3 = r3.append([tmpm])
r3 = r3.append([tmpf])
r3
# Out:
#       0 - 4     5 - 9   10 - 14   15 - 19   20 - 24  25 - 29  30 - 34  \
# 0  0.511013  0.509891  0.509457  0.508769  0.506201  0.50235  0.49743
# 0  0.488987  0.490109  0.490543  0.491231  0.493799  0.49765  0.50257
#
#     35 - 39   40 - 44   45 - 49   50 - 54   55 - 59   60 - 64   65 - 69  \
# 0  0.492849  0.486756  0.478475  0.467814  0.452632  0.432364  0.404828
# 0  0.507151  0.513244  0.521525  0.532186  0.547368  0.567636  0.595172
#
#     70 - 74   75 - 79   80 - 84
# 0  0.374081  0.338185  0.292736
# 0  0.625919  0.661815  0.707264

# %%
coef_bg_ratios = r3['0 - 4'][0].values.tolist()
coef_bg_ratios
# Out:
# [0.5110129976520625, 0.4889870023479374]

# %% [markdown]
# # Predict the change in the country's population and demographic profile for 100 years and compare with existing prediction!

# %%
# 0-4 перейдут в 5-9 - с коеф.

# %%
model_cols = cols_ext_period
print(model_cols)
# Out:
# ['Reference_date', 'Sex', '0 - 4', '5 - 9', '10 - 14', '15 - 19', '20 - 24', '25 - 29', '30 - 34', '35 - 39', '40 - 44', '45 - 49', '50 - 54', '55 - 59', '60 - 64', '65 - 69', '70 - 74', '75 - 79', '80 - 84']

# %%
# args - 
def model(coef_fertility, coef_bg_ratio, surv_rate_m, surv_rate_f, prev_record_m, prev_record_f, period_labels=cols_period):
    # res = pd.DataFrame([], columns=model_cols)
    # res.Reference_date = start_year
    
    resm = []
    resf = []
    
    resm.append(prev_record_m[0]+5)
    resf.append(prev_record_f[0]+5)

    resm.append('m')
    resf.append('f')

    tmpm = []
    for prev_period, rate in zip(prev_record_m[2:], surv_rate_m):
        alive_predict_m = (prev_period * rate)
        
        tmpm.append(alive_predict_m)
        continue

    tmpf = []
    for prev_period, rate in zip(prev_record_f[2:], surv_rate_f):
        alive_predict_f = (prev_period * rate)
        
        tmpf.append(alive_predict_f)
        continue

    women_amount = sum(tmpf[5:9])

    birthsm = (women_amount * coef_fertility) * coef_bg_ratios[0]
    resm.append(birthsm)

    birthsf = (women_amount * coef_fertility) * coef_bg_ratios[1]
    resf.append(birthsf)

    [resm.append(i) for i in tmpm]
    [resf.append(i) for i in tmpf]

    return resm, resf

# %%
pred_male, pred_female = model(
    coef_fertility=coef_fertility,
    coef_bg_ratio=coef_bg_ratios,
    surv_rate_m=surv_rate_m.values[0], surv_rate_f=surv_rate_f.values[0],
    prev_record_m = dmal.iloc[-1].values, prev_record_f= dfem.iloc[-1].values
    # ,period_labels=labels
)

print(pred_male, pred_female)
# Out:
# [2055, 'm', 385.3106782219342, 380.56748479246045, 398.8111178871337, 396.2671396556287, 384.49450089700304, 385.7173868726902, 414.73093544762884, 452.6307404407641, 463.33637410200663, 431.4739006128278, 405.6334602805468, 407.083501822852, 487.458512195447, 609.1979249092125, 452.3930175057139, 358.9065552158552, 283.9238684428301] [2055, 'f', 368.7027813031867, 360.01035311513255, 378.68920493845263, 375.95904776063287, 363.4419263929216, 366.2069580288365, 400.4529419229107, 442.10893807747306, 456.7024854986902, 431.4107687196021, 412.7084593854433, 418.5481801988975, 509.6255872611198, 671.5477773181851, 539.3080813236127, 488.0805292611136, 426.08617576000154]

# %%
dmal_pred = pd.DataFrame([pred_male], columns=cols_ext_period)
dmal_pred
# Out:
#    Reference_date Sex       0 - 4       5 - 9     10 - 14    15 - 19  \
# 0            2055   m  385.310678  380.567485  398.811118  396.26714
#
#       20 - 24     25 - 29     30 - 34    35 - 39     40 - 44     45 - 49  \
# 0  384.494501  385.717387  414.730935  452.63074  463.336374  431.473901
#
#      50 - 54     55 - 59     60 - 64     65 - 69     70 - 74     75 - 79  \
# 0  405.63346  407.083502  487.458512  609.197925  452.393018  358.906555
#
#       80 - 84
# 0  283.923868

# %%
dfem_pred = pd.DataFrame([pred_female], columns=cols_ext_period)
dfem_pred
# Out:
#    Reference_date Sex       0 - 4       5 - 9     10 - 14     15 - 19  \
# 0            2055   f  368.702781  360.010353  378.689205  375.959048
#
#       20 - 24     25 - 29     30 - 34     35 - 39     40 - 44     45 - 49  \
# 0  363.441926  366.206958  400.452942  442.108938  456.702485  431.410769
#
#       50 - 54    55 - 59     60 - 64     65 - 69     70 - 74     75 - 79  \
# 0  412.708459  418.54818  509.625587  671.547777  539.308081  488.080529
#
#       80 - 84
# 0  426.086176

# %%
prev_m = dmal[ dmal.Reference_date==2020 ]
prev_m
# Out:
#     Reference_date Sex    0 - 4    5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  \
# 746           2020   m  529.328  545.992  519.458  492.345  493.513  577.038
#
#     30 - 34  35 - 39  40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  \
# 746  727.52  584.873  510.888  463.401  370.099  415.447  325.547  241.842
#
#      70 - 74 75 - 79 80 - 84
# 746  110.007  64.368  62.016

# %%
prev_f = dfem[ dfem.Reference_date==2020 ]
prev_f
# Out:
#     Reference_date Sex    0 - 4    5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  \
# 746           2020   f  508.932  527.435  503.575  479.603  482.544  570.742
#
#      30 - 34  35 - 39  40 - 44  45 - 49 50 - 54  55 - 59  60 - 64  65 - 69  \
# 746  736.581  603.524  561.675  512.069  434.79  524.758  448.107  379.611
#
#      70 - 74  75 - 79  80 - 84
# 746  190.002  138.366  148.452

# %%
pred_male = prev_m
pred_female = prev_f

iters = 5

pred = pd.DataFrame([], columns=cols_ext_period)

for i in range(iters):
    
    pred_male, pred_female = model(
        coef_fertility=coef_fertility,
        coef_bg_ratio=coef_bg_ratios,
        surv_rate_m=surv_rate_m.values[0], surv_rate_f=surv_rate_f.values[0],
        prev_record_m = pred_male.iloc[-1].values, prev_record_f= pred_female.iloc[-1].values
        # ,period_labels=labels
    )

    pred_male = pd.DataFrame([pred_male], columns=cols_ext_period)
    pred_female = pd.DataFrame([pred_female], columns=cols_ext_period)

    pred = pred.append(pred_male)
    pred = pred.append(pred_female)

    continue

pred
# Out:
#   Reference_date Sex       0 - 4       5 - 9     10 - 14     15 - 19  \
# 0           2025   m  566.922524  543.962330  564.509487  539.429490
# 0           2025   f  542.486682  522.001011  545.493116  522.374251
# 0           2030   m  564.613898  582.596229  562.410980  586.213062
# 0           2030   f  540.277564  556.417353  539.873080  565.857236
# 0           2035   m  550.720009  580.223777  602.355160  584.033874
# 0           2035   f  526.982538  554.151507  575.467756  560.027396
# 0           2040   m  508.600856  565.945763  599.902245  625.513779
# 0           2040   f  486.678830  540.515074  573.124332  596.950877
# 0           2045   m  513.721905  522.662142  585.139988  622.966558
# 0           2045   f  491.579149  499.176396  559.021020  594.519970
#
#       20 - 24     25 - 29     30 - 34     35 - 39     40 - 44     45 - 49  \
# 0  512.091782  511.884522  599.343619  761.424718  614.543831  539.290124
# 0  495.246186  494.042144  585.491304  760.103924  622.582367  578.231757
# 0  561.064719  531.154919  531.671609  627.274914  800.052085  648.708560
# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pred_years = pred.Reference_date.unique().tolist()
print(pred_years)

compare = pd.DataFrame([], columns=cols_ext_period)
for pred_year in pred_years:
    # compare = abs(d[ (d.Sex=='m') & (d.Reference_date==2025) ][cols_period].iloc[0] - pred[ (pred.Sex=='m') & (pred.Reference_date==2025) ][cols_period].iloc[0])
    comparem = d[ (d.Sex=='m') & (d.Reference_date==pred_year) ][cols_period].iloc[0] - pred[ (pred.Sex=='m') & (pred.Reference_date==pred_year) ][cols_period].iloc[0]
    comparef = d[ (d.Sex=='f') & (d.Reference_date==pred_year) ][cols_period].iloc[0] - pred[ (pred.Sex=='f') & (pred.Reference_date==pred_year) ][cols_period].iloc[0]

    compare = compare.append(pd.DataFrame([[int(pred_year), 'm', *comparem.values.tolist()]], columns=cols_ext_period))
    compare = compare.append(pd.DataFrame([[int(pred_year), 'f', *comparef.values.tolist()]], columns=cols_ext_period))

    continue

compare
# Out:
# [2025, 2030, 2035, 2040, 2045]
#   Reference_date Sex       0 - 4       5 - 9     10 - 14     15 - 19  \
# 0           2025   m  -89.872524  -28.335330  -34.349487  -37.931490
# 0           2025   f  -85.067682  -24.858011  -33.160116  -35.373251
# 0           2030   m -132.351898 -118.118229  -62.281980  -73.774062
# 0           2030   f -127.091564 -110.138353  -57.675080  -69.974236
# 0           2035   m -138.491009 -159.682777 -153.042160 -101.275874
# 0           2035   f -134.014538 -151.615507 -143.981756  -94.115396
# 0           2040   m -101.508856 -164.919763 -194.277245 -193.228779
# 0           2040   f  -99.452830 -157.919074 -185.279332 -181.616877
# 0           2045   m -117.450905 -126.410142 -198.870988 -234.101558
# 0           2045   f -115.390149 -122.150396 -191.059020 -222.731970
#
#       20 - 24     25 - 29     30 - 34     35 - 39     40 - 44     45 - 49  \
# 0  -39.053782  -37.341522  -43.727619  -62.279718  -57.687831  -57.115124
# 0  -30.691186  -23.218144  -28.199304  -41.250924  -36.152367  -32.583757
# 0  -78.432719  -76.094919  -76.034609  -95.509914 -129.754085 -120.143560
# 0  -67.232505  -53.879001  -48.743345  -63.227136  -82.740846  -70.176519
# 0 -115.766669 -116.730923 -114.471910 -122.098176 -151.213811 -204.028894
# 0 -103.055773  -91.265722  -79.454278  -80.482446  -97.988507 -122.251331
# 0 -142.644078 -155.412288 -156.500452 -160.444253 -171.407056 -211.256402
# 0 -126.811781 -128.050905 -117.905557 -111.378425 -111.744813 -130.243884
# 0 -235.713644 -181.519322 -196.639807 -204.378556 -209.733837 -223.661438
# 0 -215.335593 -151.501468 -155.817742 -151.228094 -142.787532 -140.169196
#
#       50 - 54     55 - 59     60 - 64     65 - 69     70 - 74     75 - 79  \
# 0  -67.233062  -71.170808 -115.834175 -125.351310 -129.080173  -85.174497
# 0  -36.125300  -37.528538  -66.988754  -84.815359 -110.670511  -86.304881
# 0 -128.434213 -152.901761 -173.228078 -275.309509 -303.053615 -328.176096
# 0  -70.853525  -78.540598  -92.913676 -164.073279 -213.911408 -281.630308
# 0 -199.339862 -220.974022 -279.072269 -317.167167 -511.368772 -595.340466
# 0 -110.302401 -116.170308 -141.890993 -173.204625 -314.686168 -418.716843
# 0 -300.027687 -303.942235 -359.813649 -461.657207 -535.374003 -915.305110
# 0 -169.467457 -158.113974 -184.391587 -234.976109 -298.273234 -557.710052
# 0 -287.968126 -429.315107 -463.532393 -564.365510 -744.417453 -917.506862
# 0 -168.067337 -226.573267 -230.597474 -285.583580 -381.830775 -501.714078
#
#        80 - 84
# 0   -74.296928
# 0  -100.942749
# 0  -231.933157
# 0  -230.222841
# 0  -709.081136
# 0  -584.853945
# 0 -1186.631720
# 0  -792.940035
# 0 -1758.918287
# 0 -1011.091990

# %%
inds = [f"{year}-{sex}" for year, sex in compare[['Reference_date', 'Sex']].values.tolist()]
compare_heat = pd.DataFrame(compare[cols_period].set_index([inds]), columns=cols_period)
compare_heat
# Out:
#              0 - 4       5 - 9     10 - 14     15 - 19     20 - 24  \
# 2025-m  -89.872524  -28.335330  -34.349487  -37.931490  -39.053782
# 2025-f  -85.067682  -24.858011  -33.160116  -35.373251  -30.691186
# 2030-m -132.351898 -118.118229  -62.281980  -73.774062  -78.432719
# 2030-f -127.091564 -110.138353  -57.675080  -69.974236  -67.232505
# 2035-m -138.491009 -159.682777 -153.042160 -101.275874 -115.766669
# 2035-f -134.014538 -151.615507 -143.981756  -94.115396 -103.055773
# 2040-m -101.508856 -164.919763 -194.277245 -193.228779 -142.644078
# 2040-f  -99.452830 -157.919074 -185.279332 -181.616877 -126.811781
# 2045-m -117.450905 -126.410142 -198.870988 -234.101558 -235.713644
# 2045-f -115.390149 -122.150396 -191.059020 -222.731970 -215.335593
#
#            25 - 29     30 - 34     35 - 39     40 - 44     45 - 49  \
# 2025-m  -37.341522  -43.727619  -62.279718  -57.687831  -57.115124
# 2025-f  -23.218144  -28.199304  -41.250924  -36.152367  -32.583757
# 2030-m  -76.094919  -76.034609  -95.509914 -129.754085 -120.143560
# 2030-f  -53.879001  -48.743345  -63.227136  -82.740846  -70.176519
# 2035-m -116.730923 -114.471910 -122.098176 -151.213811 -204.028894
# 2035-f  -91.265722  -79.454278  -80.482446  -97.988507 -122.251331
# 2040-m -155.412288 -156.500452 -160.444253 -171.407056 -211.256402
# 2040-f -128.050905 -117.905557 -111.378425 -111.744813 -130.243884
# 2045-m -181.519322 -196.639807 -204.378556 -209.733837 -223.661438
# 2045-f -151.501468 -155.817742 -151.228094 -142.787532 -140.169196
#
#            50 - 54     55 - 59     60 - 64     65 - 69     70 - 74  \
# 2025-m  -67.233062  -71.170808 -115.834175 -125.351310 -129.080173
# 2025-f  -36.125300  -37.528538  -66.988754  -84.815359 -110.670511
# 2030-m -128.434213 -152.901761 -173.228078 -275.309509 -303.053615
# 2030-f  -70.853525  -78.540598  -92.913676 -164.073279 -213.911408
# 2035-m -199.339862 -220.974022 -279.072269 -317.167167 -511.368772
# 2035-f -110.302401 -116.170308 -141.890993 -173.204625 -314.686168
# 2040-m -300.027687 -303.942235 -359.813649 -461.657207 -535.374003
# 2040-f -169.467457 -158.113974 -184.391587 -234.976109 -298.273234
# 2045-m -287.968126 -429.315107 -463.532393 -564.365510 -744.417453
# 2045-f -168.067337 -226.573267 -230.597474 -285.583580 -381.830775
#
#            75 - 79      80 - 84
# 2025-m  -85.174497   -74.296928
# 2025-f  -86.304881  -100.942749
# 2030-m -328.176096  -231.933157
# 2030-f -281.630308  -230.222841
# 2035-m -595.340466  -709.081136
# 2035-f -418.716843  -584.853945
# 2040-m -915.305110 -1186.631720
# 2040-f -557.710052  -792.940035
# 2045-m -917.506862 -1758.918287
# 2045-f -501.714078 -1011.091990

# %% [markdown]
# # Comparing part. Plotting

# %%
# def plotting_compare_single(orig, pred, sex, year, title="Comparing original and predicted data (sex={0},year={1})"):
def plotting_compare_single(orig, pred, cond, title):
    plt.figure(1, figsize=(20,10))
    # plt.title(title.format(sex, year))
    plt.title(title)

    orig_cond = cond(orig)
    pred_cond = cond(pred)

    # plt.plot(orig[ (orig['Sex'] == sex) & (orig['Reference_date'] == year) ][cols_period].values.tolist()[0], color='b')
    # plt.plot(pred[ (pred['Sex'] == sex) & (pred['Reference_date'] == year) ][cols_period].values.tolist()[0], color='g')

    plt.plot(orig[orig_cond][cols_period].values.tolist()[0], color='b')
    plt.plot(pred[pred_cond][cols_period].values.tolist()[0], color='g')

    plt.xlabel('Periods')
    plt.xticks(range(0, len(cols_period)), cols_period)
    
    plt.ylabel('Population amount (in thousands)')

    plt.legend(['original data', 'predicted data'])
    plt.grid()
    plt.show()
    pass

# %% [markdown]
# Both part

# %%
plotting_compare_single(d_both, pred_both, lambda t: t['Reference_date']==2025, title="Comparing original and predicted data (year=2025)")

# %% [markdown]
# Male part

# %%
plotting_compare_single(d, pred, lambda t: (t['Sex']=='m')&(t['Reference_date']==2025), title="Comparing original and predicted data (sex='male',year=2025)")

# %% [markdown]
# Female part

# %%
plotting_compare_single(d, pred, lambda t: (t['Sex']=='f')&(t['Reference_date']==2025), title="Comparing original and predicted data (sex='female',year=2025)")

# %% [markdown]
# # Comparing part. Substration

# %%
plt.figure(1, figsize=(20,10))
heat = sns.heatmap(compare_heat, annot=True)
plt.title('Difference between original and predictions')
plt.show()

# %%
# plot с линиями (для каждого года)

# %% [markdown]
# # Saving all data in intermediante storage

# %%
# r1.to_csv('./storage/intermediante/kaz_survival_rates_f.csv', index_label='index')

# # df2.to_csv('./storage/intermediante/kaz_population_both.csv', index_label='index')
# r2.to_csv('./storage/intermediante/kaz_population_both.csv', index_label='index')

# # df3.to_csv('./storage/intermediante/kaz_boys_girls_ratio.csv', index_label='index')
# r3.to_csv('./storage/intermediante/kaz_boys_girls_ratio.csv', index_label='index')
